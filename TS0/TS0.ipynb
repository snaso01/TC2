# %% [markdown]
# #### Teoría de los Circuitos 2
#
# # Trabajo semanal 0
# #### Santiago Naso

# %% [markdown]
# ![Circuito_TS0.png](attachment:e67577c7-184f-4da9-baa1-ba24e9a726af.png)

# %% [markdown]
# ![punto 1.png](attachment:c0e6e535-fd98-4a03-95cb-7dc3e26350d1.png)

# %%
from IPython.display import IFrame
IFrame("./punto 1.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./punto 1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![punto 2.png](attachment:6db22529-634c-41d2-94c7-41a15938ec64.png)

# %%
from IPython.display import IFrame
IFrame("./punto 2.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./punto 2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # **Red Normalizada**

# %% [markdown]
# ![aaa.png](attachment:b859aa3f-e7b9-45cd-a03e-f189131e528b.png)

# %% [markdown]
# ![punto 3.png](attachment:ed6acf3d-18ef-441c-8ea3-aba964b40f1c.png)

# %%
# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np


# Librería de TC2, esta la vas a usar mucho
from pytc2.sistemas_lineales import pzmap, bodePlot

# Esta parte de código la agregamos SOLO en los notebooks para fijar el estilo de los gráficos.
#
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del jupyter notebook documento

# algún bug cuando lo hice:
plt.figure(1)
plt.close(1)

import matplotlib as mpl

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 11

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

w0 = 1
k_param = [0, 1, 10]

for k in range(len(k_param)):
    
    my_tf = TransferFunction([1, -k_param[k] * w0], [1, w0]) # k_param = R2/R1
    
    bodePlot(my_tf, fig_id=1, filter_description = 'k = {:d}'.format(k_param[k]))
    pzmap(my_tf, fig_id=2, filter_description ='k = {:d}'.format(k_param[k]))

# %% [markdown]
# ![punto 4.png](attachment:24c5de2c-4e69-4322-b620-911fc90d97a2.png)

# %% [markdown]
# ![CIRC_LTSpice.png](attachment:27581bbe-e53a-4d80-8030-72555e120d3e.png)

# %% [markdown]
# ![sim.png](attachment:40f9debd-b7df-4796-8d78-024914505a57.png)

# %% [markdown]
# ![punto 5.png](attachment:c9c84cb4-e818-44a5-a72f-39419ccb9a61.png)

# %% [markdown]
# #### <li>SI R1 << R2: **FILTRO PASABAJOS INVERTIDO**

# %% [markdown]
# #### <li>SI R1 = R2:  **FILTRO PASATODO**

# %% [markdown]
# #### <li>SI R1 >> R2: **FILTRO PASAALTOS**

# %% [markdown]
# ### Analizando el circuito MF-103, me di cuenta que no está por ninguna parte la misma red. Sin embargo, tanto esta red como la analizada desfasan la fase.
